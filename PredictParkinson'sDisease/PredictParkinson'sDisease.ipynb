# %%
# Import required libraries
import tensorflow as tf
import matplotlib as mpl
import numpy as np
import pandas as pd
from tensorflow.keras.layers import Input, Dense 
from tensorflow.keras import Sequential, regularizers
from tensorflow.keras.models import Model
from sklearn.svm import SVC
from sklearn.decomposition import PCA
from sklearn import metrics
from sklearn.manifold import Isomap

# %%
X = pd.read_csv('parkinsons.data')
X.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  ...   spread2        D2       PPE
# 0  phon_R01_S01_1      119.992       157.302  ...  0.266482  2.301442  0.284654
# 1  phon_R01_S01_2      122.400       148.650  ...  0.335590  2.486855  0.368674
# 2  phon_R01_S01_3      116.682       131.111  ...  0.311173  2.342259  0.332634
# 3  phon_R01_S01_4      116.676       137.871  ...  0.334147  2.405554  0.368975
# 4  phon_R01_S01_5      116.014       141.781  ...  0.234513  2.332180  0.410335
#
# [5 rows x 24 columns]

# %%
# Drop the `name` column 
X.drop(axis = 1, labels = ['name'], inplace = True)

# %%
# Extract the label for the data
Y = X.pop('status')

# %%
# Using sklearn split the data into train and test slits. 20% test and 80% train
from sklearn.model_selection import train_test_split as tts
x_train, x_test, y_train, y_test = tts(X,Y, test_size = .2, random_state = 12345)

# %%
# Scale the training data
from sklearn import preprocessing
scale = preprocessing.StandardScaler().fit(x_train)

# %%
# Apply scale to training and test data
x_train, x_test = scale.transform(x_train), scale.transform(x_test)

# %%
print(f'Label: {y_train.unique()}\n1: Has Parkinson \n0: Does not have Parkinsons')
# Out:
# Label: [1 0]
# 1: Has Parkinson
# 0: Does not have Parkinsons

# %%
# Convert label to one-hot
from tensorflow.keras.utils import to_categorical
y_train,y_test = to_categorical(y_train), to_categorical(y_test)

# %% [markdown]
# # Predict with neural network

# %%
def classifia(layers):
    """layers: list of the dimensions of each layer of network"""
    X = Input(x_train.shape[1],)
    model = Sequential()(X)
    model = Dense(layers[0], activation = 'relu')(model)
    if len(layers) > 2:
        for layer in layers[1:-1]:
            model = Dense(layer, activation = 'relu')(model)
    model = Dense(layers[-1], activation = 'softmax')(model)
    model = Model(inputs = X, outputs = model, name=f'classifier{len(layers)}')
    model.compile(loss = 'categorical_crossentropy', optimizer = 'Adam', metrics = ['accuracy'])
    return model

# %%
layers = [2048,2048,1024, y_train.shape[-1]]
model = classifia(layers)

# %%
model.summary()
# Out:
# Model: "classifier4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 22)]              0
# _________________________________________________________________
# sequential (Sequential)      multiple                  0
# _________________________________________________________________
# dense (Dense)                (None, 2048)              47104
# _________________________________________________________________
# dense_1 (Dense)              (None, 2048)              4196352
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 2050
# =================================================================
# Total params: 6,343,682
# Trainable params: 6,343,682
# Non-trainable params: 0
# _________________________________________________________________

# %%
m = model.fit(x_train, y_train, epochs = 100, verbose = 1)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.5018 - accuracy: 0.6667
# Epoch 2/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.3109 - accuracy: 0.8462
# Epoch 3/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.2140 - accuracy: 0.9038
# Epoch 4/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.1613 - accuracy: 0.9423
# Epoch 5/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.1636 - accuracy: 0.9231
# Epoch 6/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1073 - accuracy: 0.9295
# Epoch 7/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0774 - accuracy: 0.9808
# Epoch 8/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0781 - accuracy: 0.9679
# Epoch 9/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0379 - accuracy: 0.9872
# Epoch 10/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0309 - accuracy: 0.9872
# Epoch 11/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0124 - accuracy: 0.9936
# Epoch 12/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 13/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 14/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 15/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 16/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 17/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch
# 5/5 [==============================] - 0s 7ms/step - loss: 3.0676e-05 - accuracy: 1.0000
# Epoch 49/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.9683e-05 - accuracy: 1.0000
# Epoch 50/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.8596e-05 - accuracy: 1.0000
# Epoch 51/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.7833e-05 - accuracy: 1.0000
# Epoch 52/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.6756e-05 - accuracy: 1.0000
# Epoch 53/100
# 5/5 [==============================] - 0s 6ms/step - loss: 2.6070e-05 - accuracy: 1.0000
# Epoch 54/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.5123e-05 - accuracy: 1.0000
# Epoch 55/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.4454e-05 - accuracy: 1.0000
# Epoch 56/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.3666e-05 - accuracy: 1.0000
# Epoch 57/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.3041e-05 - accuracy: 1.0000
# Epoch 58/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.2357e-05 - accuracy: 1.0000
# Epoch 59/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.1716e-05 - accuracy: 1.0000
# Epoch 60/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.1036e-05 - accuracy: 1.0000
# Epoch 61/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.0389e-05 - accuracy: 1.0000
# Epoch 62/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.9962e-05 - accuracy: 1.0000
# Epoch 63/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.9410e-05 - accuracy: 1.0000
# Epoch 64/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.8866e-05 - accuracy: 1.0000
# Epoch 65/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.8274e-05 - accuracy: 1.0000
# Epoch 66/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.7827e-05 - accuracy: 1.0000
# Epoch 67/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.7370e-05 - accuracy: 1.0000
# Epoch 68/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.6881e-05 - accuracy: 1.0000
# Epoch 69/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.6544e-05 - accuracy: 1.0000
# Epoch 70/100
# 5/5 [==============================] - 0s 6ms/step - loss: 1.6096e-05 - accuracy: 1.0000
# Epoch 71/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.5687e-05 - accuracy: 1.0000
# Epoch 72/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.5329e-05 - accuracy: 1.0000
# Epoch 73/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.4991e-05 - accuracy: 1.0000
# Epoch 74/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.4590e-05 - accuracy: 1.0000
# Epoch 75/100
# 5/5 [==============================] - 0s 8ms/step - loss: 1.4197e-05 - accuracy: 1.0000
# Epoch 76/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.3935e-05 - accuracy: 1.0000
# Epoch 77/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.3601e-05 - accuracy: 1.0000
# Epoch 78/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.3281e-05 - accuracy: 1.0000
# Epoch 79/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.3016e-05 - accuracy: 1.0000
# Epoch 80/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.2647e-05 - accuracy: 1.0000
# Epoch 81/100
# 5/5 [==============================] - 0s 6ms/step - loss: 1.2404e-05 - accuracy: 1.0000
# Epoch 82/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.2154e-05 - accuracy: 1.0000
# Epoch 83/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.1889e-05 - accuracy: 1.0000
# Epoch 84/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.1587e-05 - accuracy: 1.0000
# Epoch 85/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.1368e-05 - accuracy: 1.0000
# Epoch 86/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.1140e-05 - accuracy: 1.0000
# Epoch 87/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.0913e-05 - accuracy: 1.0000
# Epoch 88/100
# 5/5 [==============================] - 0s 8ms/step - loss: 1.0697e-05 - accuracy: 1.0000
# Epoch 89/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.0388e-05 - accuracy: 1.0000
# Epoch 90/100
# 5/5 [==============================] - 0s 6ms/step - loss: 1.0215e-05 - accuracy: 1.0000
# Epoch 91/100
# 5/5 [==============================] - 0s 7ms/step - loss: 1.0014e-05 - accuracy: 1.0000
# Epoch 92/100
# 5/5 [==============================] - 0s 7ms/step - loss: 9.8219e-06 - accuracy: 1.0000
# Epoch 93/100
# 5/5 [==============================] - 0s 7ms/step - loss: 9.5812e-06 - accuracy: 1.0000
# Epoch 94/100
# 5/5 [==============================] - 0s 7ms/step - loss: 9.4055e-06 - accuracy: 1.0000
# Epoch 95/100
# 5/5 [==============================] - 0s 7ms/step - loss: 9.2420e-06 - accuracy: 1.0000
# Epoch 96/100
# 5/5 [==============================] - 0s 7ms/step - loss: 9.0739e-06 - accuracy: 1.0000
# Epoch 97/100
# 5/5 [==============================] - 0s 7ms/step - loss: 8.8569e-06 - accuracy: 1.0000
# Epoch 98/100
# 5/5 [==============================] - 0s 7ms/step - loss: 8.6979e-06 - accuracy: 1.0000
# Epoch 99/100
# 5/5 [==============================] - 0s 8ms/step - loss: 8.5031e-06 - accuracy: 1.0000
# Epoch 100/100
# 5/5 [==============================] - 0s 6ms/step - loss: 8.3511e-06 - accuracy: 1.0000

# %%
pred = model.predict(x_test)

# %%
print(pd.Series([np.argmax(y) for y in y_test]).value_counts())
print('Null Accuracy: ',str(round(pd.Series([np.argmax(y) for y in y_test]).value_counts().head(1)[1]/len(y_test) * 100))+'%')
print(f'Test Accuracy: {metrics.accuracy_score(y_test, np.where(pred>=.5, 1, 0)) * 100}')
print(f'Train Accuracy: {metrics.accuracy_score(y_train, np.where(model.predict(x_train)>=.5, 1, 0)) * 100}')

print()
# Confusion matrix
test = np.array([np.argmax(y) for y in y_test])
prediction = np.array([np.argmax(y) for y in np.where(model.predict(x_test)>=.5, 1, 0)])
confusion = metrics.confusion_matrix(test, prediction); print(f'Confusion:\n{confusion}')
# Out:
# 1    29
# 0    10
# dtype: int64
# Null Accuracy:  74.0%
# Test Accuracy: 94.87179487179486
# Train Accuracy: 100.0
#
# Confusion:
# [[ 9  1]
#  [ 1 28]]

# %%
TN = confusion[0,0]
TP = confusion[1,1]
FP = confusion[0,1]
FN = confusion[1,0]

# %%
print('Specificity -- ', round(TN/(FP+TN), 2))
print('Precision -- ', round(TP/(TP+FP), 2))
# Out:
# Specificity --  0.9
# Precision --  0.97

# %% [markdown]
# # Predict with SVM and dimensionality reduction

# %% [markdown]
# #### PCA for dimentionality reduction

# %%
best_score = 0

# Hyperparameter tuning
for l in range(2,10):    
    x_train, x_test, y_train, y_test = tts(X,Y, test_size = 0.20, random_state = 12)
    pca = PCA(n_components=l)
    pc = pca.fit(X)
    scale = preprocessing.StandardScaler().fit(x_train)
    x_train, x_test = scale.transform(x_train), scale.transform(x_test)
    x_train, x_test = pc.transform(x_train), pc.transform(x_test)
    for i in np.arange(start = 0.05, stop = 2.05, step = 0.05):
        for j in np.arange(start = 0.001, stop = 0.101, step = 0.001):
            model = SVC(C = i, gamma = j)
            model.fit(x_train, y_train)
            score = model.score(x_test, y_test)
            if score > best_score:
                best_score = score
                best_C = model.C
                best_gamma = model.gamma
                #best_n_neighbors = iso.n_neighbors
                best_n_components = pca.n_components
print ("The highest score obtained:", round(best_score,2))
print ("C value:", round(best_C,2))
print ("gamma value:", round(best_gamma,2))
print ("pca n_components:", best_n_components)
# Out:
# The highest score obtained: 0.87
# C value: 0.4
# gamma value: 0.08
# pca n_components: 5

# %%
pred = model.predict(x_test)
print(pd.Series( y_test.value_counts()))
print('Null Accuracy: ',str(round(y_test.value_counts().head(1)[1]/len(y_test) * 100))+'%')
print(f'Test Accuracy: {metrics.accuracy_score(y_test, np.where(pred>=.5, 1, 0)) * 100}')
print(f'Train Accuracy: {metrics.accuracy_score(y_train, np.where(model.predict(x_train)>=.5, 1, 0)) * 100}')

print()
# Confusion matrix
test = y_test
prediction =  np.where(model.predict(x_test)>=.5, 1, 0)
confusion = metrics.confusion_matrix(test, prediction); print(f'Confusion:\n{confusion}')
# Out:
# 1    29
# 0    10
# Name: status, dtype: int64
# Null Accuracy:  74.0%
# Test Accuracy: 87.17948717948718
# Train Accuracy: 94.23076923076923
#
# Confusion:
# [[ 5  5]
#  [ 0 29]]

# %% [markdown]
# #### Isomap for dimentionality reduction

# %%
best_score = 0
for k in range(2, 10):
    for l in range(2, 10):
        x_train, x_test, y_train, y_test = tts(X,Y, test_size = 0.2, random_state = 12)
        iso = Isomap(n_neighbors = k, n_components = l)
        so = iso.fit(X)
        x_train, x_test = so.transform(x_train), so.transform(x_test)
        for i in np.arange(start = 0.05, stop = 2.05, step = 0.05):
            for j in np.arange(start = 0.001, stop = 0.1, step = 0.002):
                model = SVC(C = i, gamma = j)
                model.fit(x_train, y_train)
                score = model.score(x_test, y_test)
                if score > best_score:
                    best_score = score
                    best_C = model.C
                    best_gamma = model.gamma
                    best_n_neighbors = iso.n_neighbors
                    #best_n_components = pca.n_components
print ("The highest score obtained:", round(best_score,2))
print ("C value:", round(best_C,2))
print ("gamma value:", round(best_gamma,2))
print ("pca n_components:", best_n_components)
# Out:
# The highest score obtained: 0.9
# C value: 0.8
# gamma value: 0.0
# pca n_components: 5

# %%
pred = model.predict(x_test)
print(pd.Series( y_test.value_counts()))
print('Null Accuracy: ',str(round(y_test.value_counts().head(1)[1]/len(y_test) * 100))+'%')
print(f'Test Accuracy: {metrics.accuracy_score(y_test, np.where(pred>=.5, 1, 0)) * 100}')
print(f'Train Accuracy: {metrics.accuracy_score(y_train, np.where(model.predict(x_train)>=.5, 1, 0)) * 100}')

print()
# Confusion matrix
test = y_test
prediction =  np.where(model.predict(x_test)>=.5, 1, 0)
confusion = metrics.confusion_matrix(test, prediction); print(f'Confusion:\n{confusion}')
# Out:
# 1    29
# 0    10
# Name: status, dtype: int64
# Null Accuracy:  74.0%
# Test Accuracy: 79.48717948717949
# Train Accuracy: 99.35897435897436
#
# Confusion:
# [[ 2  8]
#  [ 0 29]]
